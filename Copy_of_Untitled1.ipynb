# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51190/AIML_Rithika2303A51190-b03/blob/main/Copy_of_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lab01 introdution to python library

# %%
import numpy as np
list1=[1,2,3]
array1=np.array(list1)
array1
# Out:
# array([4, 5, 6])

# %%
list2=[4,5,6]
array2=np.array(list2)
array2
# Out:
# array([4, 5, 6])

# %%
print("add:",array1+array2)


print("sub:",array1-array2)
print("mul:",array1*array2)
print("florr:",array1%array2)

print("div:",array1/array2)
print("power:",array1**array2)
#sine function

print("sine1",np.sin(array1))

print("sine2",np.sin(array2))


#logorithm
print("natural ",np.log(array1))
print("base10 ",np.log10(array1))
print("base2 ",np.log2(array1))

#exponential
print("exponential",np.exp(array1))
# Out:
# add: [5 7 9]
# sub: [-3 -3 -3]
# mul: [ 4 10 18]
# florr: [1 2 3]
# div: [0.25 0.4  0.5 ]
# power: [  1  32 729]
# sine1 [0.84147098 0.90929743 0.14112001]
# sine2 [-0.7568025  -0.95892427 -0.2794155 ]
# natural  [0.         0.69314718 1.09861229]
# base10  [0.         0.30103    0.47712125]
# base2  [0.        1.        1.5849625]
# exponential [ 2.71828183  7.3890561  20.08553692]

# %% [markdown]
# lab1 part-02

# %%
#lab tast is to visualize the datasets or data  using matplotlib
# bulitin function
people=["vyshu","sathya","abhi","sreeja"]
age=[19,18,20,19]
weight=[55,52,60,62]
import matplotlib.pyplot as plt
plt.scatter(weight, age)
plt.scatter(age, weight)
plt.title("relation between weight and height",)
plt.ylabel("weight of patients")
plt.xlabel("weights in kgs",)
plt.show()



import matplotlib.pyplot as plt
#bar plot
plt.figure(figsize=(12,4))
plt.title("people's weight in kgs",fontsize=16,fontstyle='italic')
#main plot function 'bar'
plt.bar(x=people,height=weight,width=0.6,color='orange',edgecolor='k',alpha=0.6)
plt.xlabel("people",fontsize=15)
#plt.xticks(fontsize=14,rotation=30)
#plt.yticks(fontsize=14)
plt.ylabel("weight (in kgs",fontsize=15)
plt.show()


import numpy as np
plt.figure(figsize=(7,5))

#main plot function 'hist'
plt.hist(weight,color='red',edgecolor='k',alpha=0.75,bins=5)
plt.title("histogram of patient weight",fontsize=18)
plt.xlabel("weight in kgs",fontsize=15)
#plt.xticks(fontsize=14)

#plt.yticks(fontsize=14)
plt.show()
